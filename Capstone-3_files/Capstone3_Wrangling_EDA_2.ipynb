# %% [markdown]
# # 3 Wrangling, EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 3.1 Load genotyping data file

# %%
sample_data= pd.read_csv('Soy50K_SNPs_filtered.csv', index_col=[0])
sample_data.head()
# Out:
#             ID  PI86046  PI90208  PI219698  PI253651A  PI347550A  PI398807  \
# 0  ss715578788        2        0        -2          0          0         0
# 1  ss715578818        2        0        -2          0          0         0
# 2  ss715578923        2        0        -2          0          0         0
# 3  ss715578960        0        0         0          0          0         0
# 4  ss715579193        0        0        -2          0          0         0
#
#    PI408055A  PI408069  PI408169A  ...  PI423967  PI587906  PI587946  \
# 0          0         0          2  ...         0         0         0
# 1          0         0          2  ...         0         0         0
# 2          0         0          2  ...         0         0         0
# 3          0         0          0  ...         0         0         0
# 4          0         0          2  ...         0         0         0
#
#    PI603516  Ref_allele  Alt_allele  Missing  perc_miss   MAF_Ref   MAF_Alt
# 0        -2       14963        4858      266   1.324174  0.754906  0.245094
# 1        -2       14761        4745      581   2.892274  0.756742  0.243258
# 2        -2       13915        5887      285   1.418757  0.702707  0.297293
# 3         0       18053        1825      209   1.040422  0.908190  0.091810
# 4        -2       17246        2608      233   1.159896  0.868641  0.131359
#
# [5 rows x 20094 columns]

# %%
sample_data.shape
# Out:
# (36729, 20094)

# %%
samples= sample_data.drop(['Ref_allele','Alt_allele','Missing','perc_miss','MAF_Ref','MAF_Alt'], axis=1)
#samples.head()

# %%
# Transpose the dataframe
samples=samples.T
samples.head()
# Out:
#                  0            1            2            3            4      \
# ID         ss715578788  ss715578818  ss715578923  ss715578960  ss715579193
# PI86046              2            2            2            0            0
# PI90208              0            0            0            0            0
# PI219698            -2           -2           -2            0           -2
# PI253651A            0            0            0            0            0
#
#                  5            6            7            8            9      \
# ID         ss715579265  ss715579576  ss715579942  ss715580755  ss715580822
# PI86046              0            2            0            2            2
# PI90208              0            0            0            0            0
# PI219698             0           -2           -2           -2           -2
# PI253651A            0            0            0            0            0
#
#            ...        42184        42185        42186        42187  \
# ID         ...  ss715608834  ss715608835  ss715608836  ss715603654
# PI86046    ...            0            0            0            0
# PI90208    ...            0            0            0            0
# PI219698   ...            0            0            0            0
# PI253651A  ...            0            0            0            0
#
#                  42188        42190        42191        42192        42193  \
# ID         ss715584705  ss715639176  ss715586962  ss715623959  ss715584606
# PI86046              2            2            2            0            0
# PI90208              2            2            2            0            2
# PI219698             2            2            2            0            2
# PI253651A            2            2            2            0            2
#
#                  42194
# ID         ss715633065
# PI86046              0
# PI90208              0
# PI219698             0
# PI253651A            0
#
# [5 rows x 36729 columns]

# %%
# convert row 1 as header
samples.columns = samples.iloc[0]
samples = samples[1:]
samples.head()
# Out:
# ID        ss715578788 ss715578818 ss715578923 ss715578960 ss715579193  \
# PI86046             2           2           2           0           0
# PI90208             0           0           0           0           0
# PI219698           -2          -2          -2           0          -2
# PI253651A           0           0           0           0           0
# PI347550A           0           0           0           0           0
#
# ID        ss715579265 ss715579576 ss715579942 ss715580755 ss715580822  ...  \
# PI86046             0           2           0           2           2  ...
# PI90208             0           0           0           0           0  ...
# PI219698            0          -2          -2          -2          -2  ...
# PI253651A           0           0           0           0           0  ...
# PI347550A           0           0           0          -2           0  ...
#
# ID        ss715608834 ss715608835 ss715608836 ss715603654 ss715584705  \
# PI86046             0           0           0           0           2
# PI90208             0           0           0           0           2
# PI219698            0           0           0           0           2
# PI253651A           0           0           0           0           2
# PI347550A           0           0           0           0           2
#
# ID        ss715639176 ss715586962 ss715623959 ss715584606 ss715633065
# PI86046             2           2           0           0           0
# PI90208             2           2           0           2           0
# PI219698            2           2           0           2           0
# PI253651A           2           2           0           2           0
# PI347550A           2           2           2           2           2
#
# [5 rows x 36729 columns]

# %%
samples.shape # 20087 samples are there
# Out:
# (20087, 36729)

# %%
# First filter out those rows which does not contain any data
samples_df = samples.dropna(how = 'all')
samples_df.shape

# so, there are no empty rows
# Out:
# (20087, 36729)

# %%
samples_df['Ref_allele'] = samples_df.apply(lambda row: sum(row[1:36729]==0) ,axis=1)
samples_df['Alt_allele'] = samples_df.apply(lambda row: sum(row[1:36729]==2) ,axis=1)
samples_df['Missing'] = samples_df.apply(lambda row: sum(row[1:36729]==-2) ,axis=1)
# create percent missing column by dividing missing value with total samples#
samples_df['perc_miss']=(samples_df['Missing']/20088)*100
samples_df.head()
# Out:
# ID        ss715578788 ss715578818 ss715578923 ss715578960 ss715579193  \
# PI86046             2           2           2           0           0
# PI90208             0           0           0           0           0
# PI219698           -2          -2          -2           0          -2
# PI253651A           0           0           0           0           0
# PI347550A           0           0           0           0           0
#
# ID        ss715579265 ss715579576 ss715579942 ss715580755 ss715580822  ...  \
# PI86046             0           2           0           2           2  ...
# PI90208             0           0           0           0           0  ...
# PI219698            0          -2          -2          -2          -2  ...
# PI253651A           0           0           0           0           0  ...
# PI347550A           0           0           0          -2           0  ...
#
# ID        ss715584705 ss715639176 ss715586962 ss715623959 ss715584606  \
# PI86046             2           2           2           0           0
# PI90208             2           2           2           0           2
# PI219698            2           2           2           0           2
# PI253651A           2           2           2           0           2
# PI347550A           2           2           2           2           2
#
# ID        ss715633065 Ref_allele Alt_allele Missing  perc_miss
# PI86046             0      17455      19005     268   1.334130
# PI90208             0      21204      15452      72   0.358423
# PI219698            0      15979      13053    7696  38.311430
# PI253651A           0      20141      16513      74   0.368379
# PI347550A           2      19659      14670    2399  11.942453
#
# [5 rows x 36733 columns]

# %%
# sort dataframe by Missing
samples_df.sort_values(by='Missing', ascending=False)
# Out:
# ID        ss715578788 ss715578818 ss715578923 ss715578960 ss715579193  \
# PI189900           -2          -2          -2           0          -2
# PI567264A          -2           0          -2           0          -2
# PI506737            0           0          -2           0          -2
# PI653862           -2           2           2           2           0
# PI615446           -2           0           0           0           0
# ...               ...         ...         ...         ...         ...
# PI547847            0           0           0           0           0
# PI73585             0           0           0           0           0
# PI548242            0           0           0           0           0
# PI612719            2           2           2           0           2
# PI567767B           0           0           0           0           0
#
# ID        ss715579265 ss715579576 ss715579942 ss715580755 ss715580822  ...  \
# PI189900            0          -2          -2          -2          -2  ...
# PI567264A           0          -2          -2          -2          -2  ...
# PI506737            0           0           0           2          -2  ...
# PI653862            2          -2           0           2           2  ...
# PI615446            0          -2          -2          -2          -2  ...
# ...               ...         ...         ...         ...         ...  ...
# PI547847            0           0           0           0           0  ...
# PI73585             0           0           0           0           0  ...
# PI548242            0           0           0           0           0  ...
# PI612719            0           2           2           2           2  ...
# PI567767B           0           0           0           0           0  ...
#
# ID        ss715584705 ss715639176 ss715586962 ss715623959 ss715584606  \
# PI189900            2           0           2           2          -2
# PI567264A           2           0          -2          -2           2
# PI506737            2           2           0          -2          -2
# PI653862           -2           2           0           0           2
# PI615446            2          -2           2          -2          -2
# ...               ...         ...         ...         ...         ...
# PI547847            2           0           2           0           0
# PI73585             2           2           2           0           0
# PI548242            2           0           2           0           0
# PI612719            2           2           0           0           2
# PI567767B           2           0           2           0           0
#
# ID        ss715633065 Ref_allele Alt_allele Missing  perc_miss
# PI189900            0      15943       7617   13168  65.551573
# PI567264A           0      14225       9938   12565  62.549781
# PI506737            0      14398      10004   12326  61.360016
# PI653862            0      14066      10805   11857  59.025289
# PI615446            0      14799      10474   11455  57.024094
# ...               ...        ...        ...     ...        ...
# PI547847            0      35968        754       6   0.029869
# PI73585             2      23557      13166       5   0.024890
# PI548242            0      35889        835       4   0.019912
# PI612719            0      25655      11069       4   0.019912
# PI567767B           0      35949        775       4   0.019912
#
# [20087 rows x 36733 columns]

# %%
samples_df.shape
# Out:
# (20087, 36733)

# %% [markdown]
# ## Sample filtering by number of missing values

# %% [markdown]
#  ## Find how many samles having >10% missing data?

# %%
miss_samples=samples_df.loc[samples_df['Missing']>3673]
miss_samples.shape

# 691 samples having >10% missing 
# 138 samples with 15% missing
# 20 samples having >20% missing data
# Out:
# (691, 36733)

# %% [markdown]
# ## Filter samples with <10% missing (i.e dropping samples wiht >10% missing)

# %%
df1=samples_df.loc[samples_df['Missing']<=3673] # 2008 is 10% of 20087
df1.shape

# the 12 SNPs with >10% missing data are dropped
# Out:
# (19396, 36733)

# %%
filtered_data=df1.drop(columns=['Ref_allele','Alt_allele','Missing','perc_miss'])
filtered_data.shape
# Out:
# (19396, 36729)

# %%
filtered_data.head()
# Out:
# ID        ss715578788 ss715578818 ss715578923 ss715578960 ss715579193  \
# PI86046             2           2           2           0           0
# PI90208             0           0           0           0           0
# PI253651A           0           0           0           0           0
# PI347550A           0           0           0           0           0
# PI398807            0           0           0           0           0
#
# ID        ss715579265 ss715579576 ss715579942 ss715580755 ss715580822  ...  \
# PI86046             0           2           0           2           2  ...
# PI90208             0           0           0           0           0  ...
# PI253651A           0           0           0           0           0  ...
# PI347550A           0           0           0          -2           0  ...
# PI398807            0           0           0           0           0  ...
#
# ID        ss715608834 ss715608835 ss715608836 ss715603654 ss715584705  \
# PI86046             0           0           0           0           2
# PI90208             0           0           0           0           2
# PI253651A           0           0           0           0           2
# PI347550A           0           0           0           0           2
# PI398807            0           0           0           0           2
#
# ID        ss715639176 ss715586962 ss715623959 ss715584606 ss715633065
# PI86046             2           2           0           0           0
# PI90208             2           2           0           2           0
# PI253651A           2           2           0           2           0
# PI347550A           2           2           2           2           2
# PI398807            2           2           0           2           0
#
# [5 rows x 36729 columns]

# %%
filtered_data.to_csv('samples_SNP_filtered.csv')

# %% [markdown]
# Summary:
#
# Samples filtering:
# There 691 samples having >10% missing (138 samples with 15% missing, 20 samples having >20% missing data). Since there aren't many samples with higher missign data, I dropped samples with >10% missing data.
# After dropping samples with >10% missing data, 19396 samples are left.
